# %%
import os
import pandas as pd
from pyspark.sql import SparkSession
from pyspark.sql import functions as F

# 1. Khởi tạo Spark
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-17-openjdk-amd64"
spark = SparkSession.builder \
    .appName("Excel_to_Parquet") \
    .master("local[*]") \
    .config("spark.driver.memory", "8g") \
    .getOrCreate()

CSV = "SalesTransaction.csv"
OUTPUT_PARQUET = "data.parquet"


df = spark.read.csv(CSV, header=True, inferSchema=True)

print(f"--- Đang lưu file Parquet tại: {OUTPUT_PARQUET} ---")
df.write.mode("overwrite").parquet(OUTPUT_PARQUET)

if os.path.exists(CSV):
    os.remove(CSV)

spark.stop()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/04/15 10:49:25 WARN Utils: Your hostname, admin2025RESNAN, resolves to a loopback address: 127.0.1.1; using 172.27.14.10 instead (on interface eth0)
# 26/04/15 10:49:25 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/15 10:49:26 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/04/15 10:49:28 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# --- Đang lưu file Parquet tại: data.parquet ---
